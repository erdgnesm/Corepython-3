# %% [markdown]
# # Problem 1
# Bir sayının çift olup olmadığını sorgulayan bir fonksiyon yazın. Bu fonksiyon, eğer sayı çift ise bu değeri dönsün. Ancak sayı tek sayı ise fonksiyon raise ile ValueError hatası oluştursun. Daha sonra, içinde çift ve tek sayılar bulunduran bir liste tanımlayın ve liste üzerinde gezinerek ekrana sadece çift sayıları bastırın.

# %%
liste=[2,4,6,7,8,9,10]
def cift_mi(liste):
    for i in liste:
        if i%2==0:
            print(i)
        else:
            raise ValueError("listede tek sayı bulunuyor.")
cift_mi([2,4,6,7,8,9,10])
#raise ifadesi bir hata durumunu belirtmek için kullanılır 
#böylece program o noktada durur ve belirli bir hata mesji verir.
# Out:
# 2
# 4
# 6
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 8
#       6         else:
#       7             raise ValueError("listede tek sayı bulunuyor.")
# ----> 8 cift_mi([2,4,6,7,8,9,10])
#       9 #raise ifadesi bir hata durumunu belirtmek için kullanılır
#      10 #böylece program o noktada durur ve belirli bir hata mesji verir.
#
# Cell In[5], line 7, in cift_mi(liste)
#       5     print(i)
#       6 else:
# ----> 7     raise ValueError("listede tek sayı bulunuyor.")
#
# ValueError: listede tek sayı bulunuyor.

# %% [markdown]
# # Problem 2
#
# 2 YetGen lideri ders sırasında canları sıkılınca oyun oynamak isterler. Ancak hangi oyunu oynayacaklarına karar veremezler ve son olarak kendi oyunlarını yazmaya karar verirler.
# Liderlerimizin kodlamak istediği oyun kuralları şöyledir:
# - Oyunda random olarak 0 ile 100 arasında bir sayı tutulur.
# - Kullanıcıdan bilgisayarın tuttuğu sayıyı tahmin etmesi için bir sayı girmesini istenir.
# - Eğer kullanıcının girdiği sayı bulunması gereken sayıdan küçükse  tahmininizi yükseltin, büyükse tahmininizi düşürün şeklinde bir çıktı verilir.
# - Oyunun gerçeğe yakın olması için bilgisayarın çalışmasını simgelemek için 1 saniye bekleme süresi tanınır.
# - Kullanıcı 5 hakkı vardır. 5 hakkı da kullanıp sayıyı bulamazsa oyunu kaybeder.

# %%
import random
import time
print("--SAYI TAHMİN OYUNU")
rastgelesayi=random.randint(1,101)
tahminhakki=5
while True:
    tahmin=int(input("TAHMİN:"))
    if tahmin<rastgelesayi:
        print("SORGULANIYOR...")
        time.sleep(1)
        print("Daha yüksek bir sayı giriniz.")
        tahminhakki-=1
    elif tahmin>rastgelesayi:
        print("SORGULANIYOR...")
        time.sleep(1)
        print("Daha düşük bir sayı giriniz.")
        tahminhakki-=1
    else:
        print("SORGULANIYOR...")
        time.sleep(1)
        print("Tebrikler doğru")
        break
    if tahminhakki==0:
        print(f"TAHMİN HAKKINIZ BİTTİ. \n SAYIMIZ:{rastgelesayi} olmalıydı")
        break
# Out:
# --SAYI TAHMİN OYUNU
# SORGULANIYOR...
# Daha düşük bir sayı giriniz.
# SORGULANIYOR...
# Daha düşük bir sayı giriniz.
# SORGULANIYOR...
# Daha düşük bir sayı giriniz.
# SORGULANIYOR...
# Daha düşük bir sayı giriniz.
# SORGULANIYOR...
# Daha yüksek bir sayı giriniz.
# TAHMİN HAKKINIZ BİTTİ.
#  SAYIMIZ:11 olmalıydı
